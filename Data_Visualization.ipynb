# %% [markdown]
# <a href="https://colab.research.google.com/github/mradulpandya/Data_Analysis/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %% [markdown]
# # Histograms

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 1.,  4., 13., 10., 11., 20., 20., 11.,  6.,  4.]),
#  array([-2.42092683, -1.94928808, -1.47764933, -1.00601058, -0.53437183,
#         -0.06273308,  0.40890567,  0.88054442,  1.35218317,  1.82382192,
#          2.29546067]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 1.,  0.,  2.,  7., 10., 23., 22.,  7.,  5.,  3.]),
#  array([-3.62361319, -3.00651157, -2.38940995, -1.77230834, -1.15520672,
#         -0.53810511,  0.07899651,  0.69609812,  1.31319974,  1.93030135,
#          2.54740297]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,density=True,alpha=0.5,bins=20)
plt.hist(dataset2,density=True,color='indianred',alpha=0.5,bins=20)
# Out:
# (array([0.04051197, 0.        , 0.        , 0.        , 0.08102393,
#         0.        , 0.08102393, 0.20255983, 0.20255983, 0.20255983,
#         0.20255983, 0.7292154 , 0.40511967, 0.4861436 , 0.1215359 ,
#         0.16204787, 0.1215359 , 0.08102393, 0.04051197, 0.08102393]),
#  array([-3.62361319, -3.31506238, -3.00651157, -2.69796076, -2.38940995,
#         -2.08085915, -1.77230834, -1.46375753, -1.15520672, -0.84665592,
#         -0.53810511, -0.2295543 ,  0.07899651,  0.38754732,  0.69609812,
#          1.00464893,  1.31319974,  1.62175055,  1.93030135,  2.23885216,
#          2.54740297]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Combaining Plot Styles

# %%
dataset = randn(100)

# %%
sns.distplot(dataset,bins=25)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset,bins=25, rug=True, hist= False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset,bins=25, kde_kws={'color':'indianred','label':'KDE PLOT'}, hist_kws={'color':'blue','label':'HIST'})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from pandas import Series

# %%
ser1 = Series(dataset,name='My_Data')

# %%
ser1
# Out:
# 0     0.613398
# 1     0.252658
# 2     0.365898
# 3    -0.246255
# 4     0.276889
#         ...
# 95    0.447324
# 96    0.747378
# 97   -1.286105
# 98   -1.019657
# 99    0.353304
# Name: My_Data, Length: 100, dtype: float64

# %%
sns.distplot(ser1, bins=25)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Box and Voilin PLot

# %%
url = 'http://en.wikipedia.org/wiki/Box_plot#mediaviewer/File:Boxplot_vs_PDF.svg'

# %%
data1 = randn(100)
data2 = randn(100)

# %%
plt.boxplot([data1,data2])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f23c43d9f50>,
#   <matplotlib.lines.Line2D at 0x7f23c436f490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f23c43e12d0>,
#   <matplotlib.lines.Line2D at 0x7f23c43e1810>,
#   <matplotlib.lines.Line2D at 0x7f23c436f790>,
#   <matplotlib.lines.Line2D at 0x7f23c4379190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f23c43e72d0>,
#   <matplotlib.lines.Line2D at 0x7f23c4379b50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f23c43e7290>,
#   <matplotlib.lines.Line2D at 0x7f23c4379650>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f23c445af10>,
#   <matplotlib.lines.Line2D at 0x7f23c43e1290>,
#   <matplotlib.lines.Line2D at 0x7f23c43e7810>,
#   <matplotlib.lines.Line2D at 0x7f23c436f710>]}

# %%
plt.boxplot(data1, vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f23c42405d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f23c4240910>,
#   <matplotlib.lines.Line2D at 0x7f23c4247390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f23c4247910>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f23c42473d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f23c4294b90>,
#   <matplotlib.lines.Line2D at 0x7f23c42408d0>]}

# %%
plt.violinplot([data1,data2])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f23c417c650>,
#   <matplotlib.collections.PolyCollection at 0x7f23c417c050>],
#  'cbars': <matplotlib.collections.LineCollection at 0x7f23c413d750>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f23d08fc810>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f23c417cc90>}

# %%
plt.violinplot(data1, bw_method=0.1)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f23c3f86550>],
#  'cbars': <matplotlib.collections.LineCollection at 0x7f23c3f86b10>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f23c3f86450>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f23c3f86b50>}

# %% [markdown]
# # Regression Plots

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill','tip',tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('total_bill','tip',tips, scatter_kws={'marker':'0','color':'indianred'}, line_kws={'linewidth':1,'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('total_bill','tip',tips,fit_reg=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pect'] = 100*(tips['tip']/tips['total_bill'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.lmplot('size','tip_pect',tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# We can also add jitter to this
url = "http://en.wikipedia.org/wiki/Jitter"

# %%
sns.lmplot('size','tip_pect',tips,x_jitter=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('size','tip_pect',tips,x_estimator=np.mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='sex',markers=['x','o'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='day')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
url = 'http://en.wikipedia.org/wiki/Local_regression'

# %%
sns.lmplot("total_bill", "tip_pect", tips, lowess=True, line_kws={"color": 'black'});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot('total_bill', 'tip_pect', tips)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Heat Map and Clustered Matrices

# %%
flight_dframe = sns.load_dataset('flights')

# %%
flight_dframe.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_dframe = flight_dframe.pivot('month','year','passengers')

# %%
flight_dframe
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(flight_dframe)

# %%
sns.heatmap(flight_dframe,annot=True,fmt='d')

# %%
f,(axis1,axis2) = plt.subplots(2,1)
yearly_flights = flight_dframe.sum()

years = pd.Series(yearly_flights.index.values)
years = pd.DataFrame(years)

flights = pd.Series(yearly_flights.values) 
flights = pd.DataFrame(flights)

# Make the dframe and name columns
year_dframe = pd.concat((years,flights),axis=1)
year_dframe.columns = ['Year','Flights']



# Create the bar plot on top
sns.barplot('Year',y='Flights',data=year_dframe, ax = axis1)

# Create the heatmap on bottom
sns.heatmap(flight_dframe,cmap='Blues',ax=axis2,cbar_kws={"orientation": "horizontal"})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.clustermap(flight_dframe)

# %%
sns.clustermap(flight_dframe, col_cluster=False)

# %%
sns.clustermap(flight_dframe, standard_scale=1)

# %%
sns.clustermap(flight_dframe, standard_scale=0)

# %%
sns.clustermap(flight_dframe,z_score=1)
